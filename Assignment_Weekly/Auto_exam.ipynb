# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\maham\\Training\\Datascience\\Python_practice'

# %%
os.chdir(r'C:\Users\maham\Documents')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\maham\\Documents'

# %%
df = pd.read_csv('Auto.csv', na_values=['#NAME?'])

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized_losses         make fuel_type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num_doors   body_style drive_wheels engine_location  ...  engine_size  \
# 0       two  convertible          rwd           front  ...          130
# 1       two  convertible          rwd           front  ...          130
# 2       two    hatchback          rwd           front  ...          152
# 3      four        sedan          fwd           front  ...          109
# 4      four        sedan          4wd           front  ...          136
#
# ...

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized_losses         make fuel_type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     aspiration num_doors   body_style drive_wheels engine_location  ...  \
# ...

# %% [markdown]
# # Find the most expensive car company name

# %%
highest_price = max(df['price'])

# %%
highest_price
# Out:
# 45400.0

# %%
make_of_most_expensive_car = df[df['price'] == highest_price]['make'].to_string(index=False).strip()

# %%
make_of_most_expensive_car
# Out:
# 'mercedes-benz'

# %% [markdown]
# # Count total cars per company

# %%
df = pd.read_csv("C:\\Users\\maham\\Documents\\Auto.csv")
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# # Find each company’s highest price car

# %%
df = pd.read_csv("C:\\Users\\maham\\Documents\\Auto.csv")
car_Manufacturers = df.groupby('make')
priceDf = car_Manufacturers['make','price'].max()
priceDf
# Out:
# C:\Users\maham\AppData\Local\Temp/ipykernel_13588/579114274.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = car_Manufacturers['make','price'].max()
#                         make    price
# make
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# ...

# %% [markdown]
# # Sort all cars by Price column

# %%
carsDf = pd.read_csv("C:\\Users\\maham\\Documents\\Auto.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(5)
# Out:
#      Unnamed: 0  symboling  normalized_losses           make fuel_type  \
# 74           74          1                NaN  mercedes-benz       gas
# 16           16          0                NaN            bmw       gas
# 73           73          0                NaN  mercedes-benz       gas
# 128         128          3                NaN        porsche       gas
# 17           17          0                NaN            bmw       gas
#
#     aspiration num_doors   body_style drive_wheels engine_location  ...  \
# 74         std       two      hardtop          rwd           front  ...
# 16         std       two        sedan          rwd           front  ...
# 73         std      four        sedan          rwd           front  ...
# 128        std       two  convertible          rwd            rear  ...
# 17         std      four        sedan          rwd           front  ...
#
#      engine_size  fuel_system  bore  stroke  compression_ratio horsepower  \
# ...
